# %%
import pandas as pd

# %%
datos=pd.read_csv('vgsales.csv')
datos
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
Yea=datos['Year']
Yea
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16593    2002.0
# 16594    2003.0
# 16595    2008.0
# 16596    2010.0
# 16597    2003.0
# Name: Year, Length: 16598, dtype: float64

# %%
Yea.shape
# Out:
# (16598,)

# %%
Yea.hist(bins=3)
# Out:
# <Axes: >

# %%
New=datos['Year']
New
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16593    2002.0
# 16594    2003.0
# 16595    2008.0
# 16596    2010.0
# 16597    2003.0
# Name: Year, Length: 16598, dtype: float64

# %%
(New[New<1994])
# Out:
# 1        1985.0
# 5        1989.0
# 9        1984.0
# 18       1990.0
# 21       1989.0
#           ...
# 14507    1988.0
# 14599    1992.0
# 15867    1985.0
# 16073    1992.0
# 16105    1993.0
# Name: Year, Length: 365, dtype: float64

# %%
New.shape
# Out:
# (16598,)

# %%
New.hist(bins=3)
# Out:
# <Axes: >

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
datos['EU_Sales'].value_counts()
# Out:
# 0.00     5730
# 0.01     1496
# 0.02     1269
# 0.03      934
# 0.04      748
#          ...
# 3.42        1
# 2.38        1
# 1.99        1
# 2.10        1
# 29.02       1
# Name: EU_Sales, Length: 305, dtype: int64

# %%
datos['EU_Sales'].describe()
# Out:
# count    16598.000000
# mean         0.146652
# std          0.505351
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.110000
# max         29.020000
# Name: EU_Sales, dtype: float64

# %%
datos=datos.sort_values(by='Year',ascending=True).reset_index(drop=True)
datos
# Out:
#         Rank                         Name Platform    Year         Genre  \
# 0       6898                     Checkers     2600  1980.0          Misc
# 1       2671                       Boxing     2600  1980.0      Fighting
# 2       5368                      Freeway     2600  1980.0        Action
# 3       1971                     Defender     2600  1980.0          Misc
# 4       1768                      Kaboom!     2600  1980.0          Misc
# ...      ...                          ...      ...     ...           ...
# 16593  16310                Freaky Flyers       GC     NaN        Racing
# 16594  16330                    Inversion       PC     NaN       Shooter
# 16595  16369  Hakuouki: Shinsengumi Kitan      PS3     NaN     Adventure
# 16596  16430                 Virtua Quest       GC     NaN  Role-Playing
# 16597  16496                   The Smurfs      3DS     NaN        Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
datos=datos.sort_values(by='Year',ascending=False).reset_index(drop=True)
datos
# Out:
#         Rank                                              Name Platform  \
# 0       5959                            Imagine: Makeup Artist       DS
# 1      16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 2      14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 3      16441                  Brothers Conflict: Precious Baby      PSV
# 4      15284                Hyakka Hyakurou: Sengoku Ninpoujou      PSV
# ...      ...                                               ...      ...
# 16593  16310                                     Freaky Flyers       GC
# 16594  16330                                         Inversion       PC
# 16595  16369                       Hakuouki: Shinsengumi Kitan      PS3
# 16596  16430                                      Virtua Quest       GC
# 16597  16496                                        The Smurfs      3DS
#
#          Year         Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games=datos['Platform']
games
# Out:
# 0         DS
# 1        PSV
# 2        PS4
# 3        PSV
# 4        PSV
#         ...
# 16593     GC
# 16594     PC
# 16595    PS3
# 16596     GC
# 16597    3DS
# Name: Platform, Length: 16598, dtype: object

# %%
datos_ordenados=datos.sort_values('Global_Sales',ascending=False)
datos
# Out:
#         Rank                                              Name Platform  \
# 0       5959                            Imagine: Makeup Artist       DS
# 1      16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 2      14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 3      16441                  Brothers Conflict: Precious Baby      PSV
# 4      15284                Hyakka Hyakurou: Sengoku Ninpoujou      PSV
# ...      ...                                               ...      ...
# 16593  16310                                     Freaky Flyers       GC
# 16594  16330                                         Inversion       PC
# 16595  16369                       Hakuouki: Shinsengumi Kitan      PS3
# 16596  16430                                      Virtua Quest       GC
# 16597  16496                                        The Smurfs      3DS
#
#          Year         Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
juegos_mas_vendidos=datos_ordenados.head(10)
juegos_mas_vendidos
# Out:
#        Rank                       Name Platform    Year         Genre  \
# 10156     1                 Wii Sports      Wii  2006.0        Sports
# 16197     2          Super Mario Bros.      NES  1985.0      Platform
# 7971      3             Mario Kart Wii      Wii  2008.0        Racing
# 5909      4          Wii Sports Resort      Wii  2009.0        Sports
# 15578     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 16125     6                     Tetris       GB  1989.0        Puzzle
# 9958      7      New Super Mario Bros.       DS  2006.0      Platform
# 9865      8                   Wii Play      Wii  2006.0          Misc
# 5919      9  New Super Mario Bros. Wii      Wii  2009.0      Platform
# 16216    10                  Duck Hunt      NES  1984.0       Shooter
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 10156  Nintendo     41.49     29.02      3.77         8.46         82.74
# ...

# %%
datos_filtrados=datos[(datos['Year'] >=2009) & (datos['Year'] <=2012)]
datos_filtrados
# Out:
#        Rank                         Name Platform    Year      Genre  \
# 2090   3419                SoulCalibur V     X360  2012.0   Fighting
# 2091  11605               Rayman Origins       PC  2012.0   Platform
# 2092  11678  Need for Speed: Most Wanted       PC  2012.0     Racing
# 2093  16303        Tsuyo Kiss 3 Portable      PSP  2012.0     Action
# 2094   3169                 Gravity Rush      PSV  2012.0     Action
# ...     ...                          ...      ...     ...        ...
# 6571   8754        Jewel Quest Solitaire       DS  2009.0     Puzzle
# 6572   8757            Cars: Race-O-Rama     X360  2009.0     Racing
# 6573   7361    Hannah Montana: The Movie     X360  2009.0  Adventure
# 6574   7362   50 Cent: Blood on the Sand     X360  2009.0    Shooter
# 6575   4721                           Up      PSP  2009.0     Action
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
datos_ordenados=datos_filtrados.sort_values('Global_Sales',ascending=False)
datos_ordenados
# Out:
#        Rank                                               Name Platform  \
# 5909      4                                  Wii Sports Resort      Wii
# 5919      9                          New Super Mario Bros. Wii      Wii
# 6173     15                                       Wii Fit Plus      Wii
# 4837     16                                 Kinect Adventures!     X360
# 4099     27                        Pokemon Black/Pokemon White       DS
# ...     ...                                                ...      ...
# 3451  16132                 Umineko no Naku Koro ni Portable 1      PSP
# 2344  16052                        Abunai: Koi no Sousa Shitsu      PSP
# 6184  16100                                      Super PickUps      Wii
# 3161  16548  The Treasures of Mystery Island 3 Pack - Save ...       PC
# 4190  16265                    Hanayaka Kana, Ware ga Ichizoku      PSP
#
#         Year         Genre               Publisher  NA_Sales  EU_Sales  \
# ...

# %%
juegos_mas_vendidos=datos_ordenados.head(5)
juegos_mas_vendidos
# Out:
#       Rank                         Name Platform    Year         Genre  \
# 5909     4            Wii Sports Resort      Wii  2009.0        Sports
# 5919     9    New Super Mario Bros. Wii      Wii  2009.0      Platform
# 6173    15                 Wii Fit Plus      Wii  2009.0        Sports
# 4837    16           Kinect Adventures!     X360  2010.0          Misc
# 4099    27  Pokemon Black/Pokemon White       DS  2010.0  Role-Playing
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 5909                Nintendo     15.75     11.01      3.28         2.96
# 5919                Nintendo     14.59      7.06      4.70         2.26
# 6173                Nintendo      9.09      8.59      2.53         1.79
# 4837  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 4099                Nintendo      5.57      3.28      5.65         0.82
#
#       Global_Sales
# 5909         33.00
# 5919         28.62
# 6173         22.00
# 4837         21.82
# ...

# %%
juegos_microsoft=datos[datos['Platform']=='GB']
juegos_microsoft
# Out:
#        Rank                                               Name Platform  \
# 13571   896                The Legend of Zelda: Oracle of Ages       GB
# 13646   925             The Legend of Zelda: Oracle of Seasons       GB
# 13681  4956  From TV Animation One Piece: Yume no Lufy Kaiz...       GB
# 13703  1030              Harry Potter and the Sorcerer's Stone       GB
# 13710  1193                            Dragon Quest Monsters 2       GB
# ...     ...                                                ...      ...
# 16132    22                                   Super Mario Land       GB
# 16134  1144                                           Baseball       GB
# 16135  1544                                            Yakuman       GB
# 16146  1352                                 Disney's DuckTales       GB
# 16348  2021                               Donkey Kong Land III       GB
#
#          Year         Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
juegos_microsoft.shape
# Out:
# (98, 11)

# %%
juegos_mas_vendidos=datos[(datos['Global_Sales'] >=10) & (datos['Year']==2009)]
juegos_mas_vendidos
# Out:
#       Rank                                  Name Platform    Year     Genre  \
# 5909     4                     Wii Sports Resort      Wii  2009.0    Sports
# 5919     9             New Super Mario Bros. Wii      Wii  2009.0  Platform
# 6149    56        Call of Duty: Modern Warfare 2      PS3  2009.0   Shooter
# 6173    15                          Wii Fit Plus      Wii  2009.0    Sports
# 6294    37        Call of Duty: Modern Warfare 2     X360  2009.0   Shooter
# 6459    46  Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0    Action
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 5909    Nintendo     15.75     11.01      3.28         2.96         33.00
# 5919    Nintendo     14.59      7.06      4.70         2.26         28.62
# 6149  Activision      4.99      3.69      0.38         1.63         10.69
# 6173    Nintendo      9.09      8.59      2.53         1.79         22.00
# ...

# %%
juegos_shooter=datos[datos['Genre']=='Shooter']
juegos_shooter
# Out:
#         Rank                                  Name Platform    Year    Genre  \
# 17       847             Tom Clancy's The Division     XOne  2016.0  Shooter
# 28     15342             Homefront: The Revolution       PC  2016.0  Shooter
# 62     12135                       Resident Evil 6      PS4  2016.0  Shooter
# 70     13438  Plants vs. Zombies: Garden Warfare 2       PC  2016.0  Shooter
# 71      2446                             Overwatch     XOne  2016.0  Shooter
# ...      ...                                   ...      ...     ...      ...
# 16567  15002           Wii de Asobu: Metroid Prime      Wii     NaN  Shooter
# 16568  15200                                 Saint      Wii     NaN  Shooter
# 16577  15720                       Without Warning       XB     NaN  Shooter
# 16591  16232           Brothers in Arms: Furious 4     X360     NaN  Shooter
# 16594  16330                             Inversion       PC     NaN  Shooter
#
# ...
